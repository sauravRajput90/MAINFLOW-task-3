# %%
# Data Visualization with matplotlib

# %%
# IMPORT REQUIRED LIBRARIES FOR CLUSTERINGimport numpy as np
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
#READING THE DATASET
df =pd.read_csv("E:\INTERSHIP\Main FLOW\Financial-Analytics-data1.csv")

# %%
# OBSERVING FIRST FIVE ROWS
df.head(12)
# Out:
#                Name  Mar Cap - Crore  Sales Qtr - Crore Market_Cap_Category  \
# 0    Reliance Inds.        583436.72           99810.00           Large Cap
# 1               TCS        563709.84           30904.00           Large Cap
# 2         HDFC Bank        482953.59           20581.27           Large Cap
# 3               ITC        320985.27            9772.02           Large Cap
# 4           H D F C        289497.37           16840.51           Large Cap
# 5    Hind. Unilever        288265.26            8590.00           Large Cap
# 6     Maruti Suzuki        263493.81           19283.20           Large Cap
# 7           Infosys        248320.35           17794.00           Large Cap
# 8           O N G C        239981.50           22995.88           Large Cap
# 9    St Bk of India        232763.33           57014.08           Large Cap
# 10       ICICI Bank        203802.35           13665.35           Large Cap
# ...

# %%
#OBSERVING LAST FIVE ROWS
df.tail(10)
# Out:
#                 Name  Mar Cap - Crore  Sales Qtr - Crore Market_Cap_Category  \
# 449  Firstsour.Solu.          3139.94             887.24      Very Small Cap
# 450  Kaveri Seed Co.          3125.83              70.64      Very Small Cap
# 451  Star Ferro Cem.          3115.98             393.49      Very Small Cap
# 452     Deepak Fert.          3079.06            1644.92      Very Small Cap
# 453    Va Tech Wabag          3041.93             460.89      Very Small Cap
# 454      Prime Focus          3031.50             609.61      Very Small Cap
# 455  Lak. Vilas Bank          3029.57             790.17      Very Small Cap
# 456            NOCIL          3026.26             249.27      Very Small Cap
# 457    Orient Cement          3024.32             511.53      Very Small Cap
# 458  Natl.Fertilizer          3017.07            2840.75      Very Small Cap
#
#     Sales_Qrt_Category
# 449          Low Sales
# 450     Very Low Sales
# 451     Very Low Sales
# 452       Medium Sales
# ...

# %%
df.min()
# Out:
# Name                     3M India
# Mar Cap - Crore           3017.07
# Sales Qtr - Crore             0.0
# Market_Cap_Category     Large Cap
# Sales_Qrt_Category     High Sales
# dtype: object

# %%
df.max()
# Out:
# Name                   eClerx Services
# Mar Cap - Crore              583436.72
# Sales Qtr - Crore            110666.93
# Market_Cap_Category     Very Small Cap
# Sales_Qrt_Category      Very Low Sales
# dtype: object

# %%
#CHECKING FOR NUMBER OF ROWS AND COLUMNS
df.shape
# Out:
# (459, 5)

# %%
#LET'S SEE THE DESCRIPTIVE SUMMARY
df.describe(include='all')
# Out:
#                   Name  Mar Cap - Crore  Sales Qtr - Crore  \
# count              459       459.000000         459.000000
# unique             459              NaN                NaN
# top     Reliance Inds.              NaN                NaN
# freq                 1              NaN                NaN
# mean               NaN     28870.974139        3807.789412
# std                NaN     60557.081792        9989.449987
# min                NaN      3017.070000           0.000000
# 25%                NaN      4942.815000         534.910000
# 50%                NaN     10442.090000        1137.170000
# 75%                NaN     24707.320000        2730.195000
# max                NaN    583436.720000      110666.930000
#
#        Market_Cap_Category Sales_Qrt_Category
# count                  459                459
# unique                   4                  4
# top              Large Cap         High Sales
# freq                   119                115
# ...

# %%
#BASIC INFORMATION OF DATASET
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 459 entries, 0 to 458
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 459 non-null    object
#  1   Mar Cap - Crore      459 non-null    float64
#  2   Sales Qtr - Crore    459 non-null    float64
#  3   Market_Cap_Category  459 non-null    object
#  4   Sales_Qrt_Category   459 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 18.1+ KB

# %%
#LOOKING FOR DUPLICATES
df.duplicated().sum()
# Out:
# 0

# %%
#DROPPING DUPLICATES
df.drop_duplicates()
# Out:
#                 Name  Mar Cap - Crore  Sales Qtr - Crore Market_Cap_Category  \
# 0     Reliance Inds.        583436.72           99810.00           Large Cap
# 1                TCS        563709.84           30904.00           Large Cap
# 2          HDFC Bank        482953.59           20581.27           Large Cap
# 3                ITC        320985.27            9772.02           Large Cap
# 4            H D F C        289497.37           16840.51           Large Cap
# ..               ...              ...                ...                 ...
# 454      Prime Focus          3031.50             609.61      Very Small Cap
# 455  Lak. Vilas Bank          3029.57             790.17      Very Small Cap
# 456            NOCIL          3026.26             249.27      Very Small Cap
# 457    Orient Cement          3024.32             511.53      Very Small Cap
# 458  Natl.Fertilizer          3017.07            2840.75      Very Small Cap
#
#     Sales_Qrt_Category
# ...

# %%
#COUNTING UNIQUE VALUES
df.nunique()
# Out:
# Name                   459
# Mar Cap - Crore        459
# Sales Qtr - Crore      459
# Market_Cap_Category      4
# Sales_Qrt_Category       4
# dtype: int64

# %%
#CHECKING FOR NON VALUES 
df.loc[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Name, Mar Cap - Crore, Sales Qtr - Crore, Market_Cap_Category, Sales_Qrt_Category]
# Index: []

# %%
# DROPING ROWS HAVING MISSING VALUES
df=df.dropna()
df.shape
# Out:
# (459, 5)

# %% [markdown]
# DATA VISUALIZATION

# %%
import pandas as pd

# Sample data
data = {'Company': ['TCS', 'HDFC Bank', 'Reliance Inds.', '	Hind. Unilever', 'ITC	'], 'Sales Qtr - Crore': [8000, 9000, 7000, 8500, 6500, 5500, 4500, 3500, 3000, 2500]}

# Create DataFrame
sales_data = pd.DataFrame(df)

# Sort by 'Sales Qtr - Crore' in descending order and select top 10
top_10_sales = sales_data.sort_values(by='Sales Qtr - Crore', ascending=False)[:10]

print(top_10_sales)
# Out:
#                 Name  Mar Cap - Crore  Sales Qtr - Crore Market_Cap_Category  \
# 14           I O C L        178017.48          110666.93           Large Cap
# 0     Reliance Inds.        583436.72           99810.00           Large Cap
# 23       Tata Motors        117071.87           74156.07           Large Cap
# 27           B P C L         98278.00           60616.36           Large Cap
# 53           H P C L         58034.78           57474.25           Large Cap
# 9     St Bk of India        232763.33           57014.08           Large Cap
# 120   Rajesh Exports         23495.54           41304.84             Mid Cap
# 40        Tata Steel         73376.14           32464.14           Large Cap
# 1                TCS        563709.84           30904.00           Large Cap
# 13   Larsen & Toubro        180860.74           28747.45           Large Cap
#
#     Sales_Qrt_Category
# 14          High Sales
# 0           High Sales
# 23          High Sales
# 27          High Sales
# ...

# %%
companies = ["I O C L", "Reliance Inds.", "Tata Motors", "B P C L", "H P C L",
             "St Bk of India", "Rajesh Exports", "Tata Steel", "TCS", "Larsen & Toubro"]
market_cap = [100000, 120000, 80000, 90000, 70000, 60000, 50000, 40000, 30000, 20000]  
sales = [8000, 9000, 7000, 8500, 6500, 5500, 4500, 3500, 3000, 2500]  

plt.bar(companies, market_cap, label='Market Cap - Crore')   
plt.xlabel('Companies')
plt.ylabel('Values (in Crore)')
plt.title('Company Market Cap ')
plt.legend()
plt.xticks(rotation=45, ha='right') 
plt.show()

# %%
companies = ["I O C L", "Reliance Inds.", "Tata Motors", "B P C L", "H P C L",
             "St Bk of India", "Rajesh Exports", "Tata Steel", "TCS", "Larsen & Toubro"]
market_cap = [100000, 120000, 80000, 90000, 70000, 60000, 50000, 40000, 30000, 20000]  
sales = [8000, 9000, 7000, 8500, 6500, 5500, 4500, 3500, 3000, 2500]  
plt.bar(companies,sales)  
plt.bar(companies, sales,label='Sales Qtr - Crore') 
plt.xlabel('Companies')
plt.ylabel('Values (in Crore)')
plt.title('Company  Sales')
plt.legend()
plt.xticks(rotation=45, ha='right') 
plt.show()

# %%
companies = ["I O C L", "Reliance Inds.", "Tata Motors", "B P C L", "H P C L",
             "St Bk of India", "Rajesh Exports", "Tata Steel", "TCS", "Larsen & Toubro"]
market_cap = [100000, 120000, 80000, 90000, 70000, 60000, 50000, 40000, 30000, 20000] 
sales = [8000, 9000, 7000, 8500, 6500, 5500, 4500, 3500, 3000, 2500]  

plt.bar(companies, market_cap, label='Market Cap - Crore')  
plt.bar(companies, sales, bottom=market_cap, label='Sales Qtr - Crore')  
plt.xlabel('Companies')
plt.ylabel('Values (in Crore)')
plt.title('Company Market Cap and Sales')
plt.xticks(rotation=65, ha='right') 
plt.legend()
plt.show()

# %%
market_cap = ([100000, 120000, 80000, 90000, 70000, 60000, 50000, 40000, 30000, 20000])
plt.plot(market_cap)
plt.show()

# %%
market_cap = ([100000, 120000, 80000, 90000, 70000, 60000, 50000, 40000, 30000, 20000])
plt.plot(market_cap,marker="s",alpha=0.5)
plt.show()

# %%
sales = ([8000, 9000, 7000, 8500, 6500, 5500, 4500, 3500, 3000, 2500])
plt.plot(sales,marker="s",color="orange")
plt.show()

# %%
market_cap = [100000, 120000, 80000, 90000, 70000, 60000, 50000, 40000, 30000, 20000] 
sales = [8000, 9000, 7000, 8500, 6500, 5500, 4500, 3500, 3000, 2500] 
plt.plot(market_cap,alpha=1)
plt.plot(sales,alpha=1,color="orange")
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
sales = [8000, 9000, 7000, 8500, 6500, 5500, 4500, 3500, 3000, 2500] 
companies = ["I O C L", "Reliance Inds.", "Tata Motors", "B P C L", "H P C L",
             "St Bk of India", "Rajesh Exports", "Tata Steel", "TCS", "Larsen & Toubro"]
plt.plot(companies,sales,marker="s",color="orange")
plt.xlabel('Companies')
plt.ylabel('Values (in Crore)')
plt.title('Company sales ')
plt.xticks(rotation=45, ha='right')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
market_cap = [100000, 120000, 80000, 90000, 70000, 60000, 50000, 40000, 30000, 20000] 
companies = ["I O C L", "Reliance Inds.", "Tata Motors", "B P C L", "H P C L",
             "St Bk of India", "Rajesh Exports", "Tata Steel", "TCS", "Larsen & Toubro"]
plt.plot(companies,market_cap,marker="s")
plt.xlabel('Companies')
plt.ylabel('Values (in Crore)')
plt.title('Company Market Cap ')
plt.xticks(rotation=45, ha='right')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
market_cap = [100000, 120000, 80000, 90000, 70000, 60000, 50000, 40000, 30000, 20000] 
sales = [8000, 9000, 7000, 8500, 6500, 5500, 4500, 3500, 3000, 2500] 
companies = ["I O C L", "Reliance Inds.", "Tata Motors", "B P C L", "H P C L",
             "St Bk of India", "Rajesh Exports", "Tata Steel", "TCS", "Larsen & Toubro"]
plt.plot(companies,market_cap,marker="s")
plt.plot(companies,sales,marker="s",color="orange")
plt.xlabel('Companies')
plt.ylabel('Values (in Crore)')
plt.title('Company Market Cap ')
plt.xticks(rotation=45, ha='right')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
